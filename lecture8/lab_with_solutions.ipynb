# %%
# !pip install nltk gensim scikit-learn plotly pandas numpy
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from nltk.corpus import gutenberg
from gensim.models import Word2Vec
import gensim.downloader
from sklearn.manifold import TSNE
from matplotlib import pyplot
import plotly.express as px
import pandas as pd
import nltk
import numpy as np
nltk.download('gutenberg')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Helper function, you don't need to look into it.
def plot_vectors(X, annotations):
  X_embedded = TSNE(n_components=2, learning_rate='auto', init='random', perplexity=1).fit_transform(X)
  df = pd.DataFrame({'x': X_embedded[:, 0], 'y': X_embedded[:, 1], 'word': annotations})
  fig = px.scatter(df, x='x', y='y', text='word')
  fig.update_traces(textposition='top center')
  fig.show()

# %% [markdown]
# # Part 1: Computing word embeddings using Gensim

# %%
# Loading the moby dick book corpus
sents = gutenberg.sents("melville-moby_dick.txt")
sents = [[word.lower() for word in sent] for sent in sents]  # lowercasing

# %%
print("First sentence:", sents[0])
print("First token in the first sentence:", sents[0][0])
# Out:
# First sentence: ['[', 'moby', 'dick', 'by', 'herman', 'melville', '1851', ']']
# First token in the first sentence: [

# %%
# Training the word2vec model is done in a single line.
# You can look into the Word2Vec class documentation for more details:
# https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html#training-parameters

model = Word2Vec(sentences=sents, vector_size=100, window=5, min_count=1, workers=4).wv

# %%
# After trained, you can access the vectors like this.
# This object is a matrix where each row contains a 100-dimensional vector for each word in the corpus
model.vectors
# Out:
# array([[-0.5320066 ,  0.60895914,  0.74197096, ..., -1.2468467 ,
#          0.37878513, -0.34865418],
#        [-1.4048043 ,  0.58256745,  0.683545  , ..., -1.677661  ,
#          0.02127505, -0.08101843],
#        [-0.60232043,  0.5081137 ,  0.608041  , ..., -1.645509  ,
#          0.28029907, -0.71081394],
#        ...,
#        [-0.0140667 ,  0.01302827,  0.00656067, ..., -0.01939547,
#         -0.00764215, -0.00904919],
#        [-0.00848363,  0.00884129,  0.01365014, ..., -0.01511274,
#         -0.00686057, -0.01201881],
#        [ 0.00363769, -0.00210491, -0.0033391 , ..., -0.00400686,
#          0.00455777, -0.00727988]], dtype=float32)

# %%
model.vectors.shape  # (n_words, 100) matrix
# Out:
# (17225, 100)

# %%
# Mapping of words to indices in the matrix
print(model.key_to_index)
# Out:
# {',': 0, 'the': 1, '.': 2, 'of': 3, 'and': 4, 'a': 5, 'to': 6, 'in': 7, ';': 8, 'that': 9, "'": 10, '-': 11, 'his': 12, 'it': 13, 'i': 14, 'he': 15, 'but': 16, 's': 17, 'as': 18, 'is': 19, 'with': 20, 'was': 21, 'for': 22, 'all': 23, '"': 24, 'this': 25, 'at': 26, '!': 27, 'whale': 28, 'by': 29, 'not': 30, '--': 31, 'from': 32, 'him': 33, 'so': 34, 'on': 35, 'be': 36, 'one': 37, 'you': 38, 'there': 39, 'now': 40, 'had': 41, 'have': 42, 'or': 43, 'were': 44, 'they': 45, 'which': 46, 'like': 47, '?': 48, 'me': 49, 'then': 50, 'their': 51, 'some': 52, 'what': 53, 'when': 54, 'are': 55, 'an': 56, 'my': 57, 'no': 58, 'upon': 59, 'out': 60, 'man': 61, 'into': 62, 'up': 63, 'ship': 64, 'ahab': 65, 'more': 66, '."': 67, 'if': 68, 'them': 69, 'ye': 70, 'we': 71, 'sea': 72, 'old': 73, 'would': 74, 'other': 75, 'been': 76, 'over': 77, 'these': 78, 'will': 79, 'though': 80, 'down': 81, 'only': 82, 'its': 83, 'such': 84, 'who': 85, 'yet': 86, 'head': 87, 'boat': 88, 'time': 89, 'long': 90, 'her': 91, 'captain': 92, 'any': 93, 'here': 94, 'very': 95, '!"': 96, 'still': 97, 'about': 98, 'than': 99, 'do': 100, 'those': 101, 'great': 102, 'said': 103, ',"': 104, 'before': 105, 'two': 106, 'has': 107, 't': 108, 'must': 109, 'seemed': 110, 'most': 111, 'white': 112, 'last': 113, 'see': 114, 'thou': 115, 'way': 116, 'after': 117, 'whales': 118, 'again': 119, '?"': 120, 'did': 121, 'stubb': 122, 'how': 123, 'queequeg': 124, 'your': 125, 'little': 126, 'round': 127, 'while': 128, 'three': 129, 'say': 130, 'sperm': 131, 'men': 132, 'may': 133, 'can': 134, 'first': 135, 'through': 136, 'every': 137, 'well': 138, 'us': 139, 'being': 140, 'much': 141, 'off': 142, 'where': 143, 'good': 144, 'could': 145, 'same': 146, 'hand': 147, '(': 148, 'side': 149, 'our': 150, 'ever': 151, 'never': 152, 'look': 153, 'own': 154, 'himself': 155, 'starbuck': 156, 'deck': 157, 'almost': 158, 'go': 159, 'even': 160, 'water': 161, 'thing': 162, 'too': 163, 'should': 164, 'away': 165, 'might': 166, 'come': 167, 'made': 168, 'day': 169, 'world': 170, 'sir': 171, 'life': 172, 'pequod': 173, 'chapter': 174, 'fish': 175, 'among': 176, 'many': 177, 'far': 178, 'seen': 179, 'back': 180, ':': 181, 'line': 182, 'let': 183, 'nor': 184, 'without': 185, 'eyes': 186, 'oh': 187, 'cried': 188, 'aye': 189, 'know': 190, 'god': 191, 'sort': 192, 'right': 193, 'thought': 194, 'night': 195, 'part': 196, 'once': 197, 'boats': 198, 'air': 199, '!--': 200, 'crew': 201, 'don': 202, 'take': 203, 'whole': 204, 'half': 205, 'tell': 206, 'against': 207, 'thus': 208, 'things': 209, 'thee': 210, 'whaling': 211, 'came': 212, 'hands': 213, 'soon': 214, 'mast': 215, 'each': 216, 'small': 217, 'feet': 218, 'both': 219, 'full': 220, 'something': 221, 'till': 222, 'think': 223, 'she': 224, 'between': 225, 'under': 226, 'why': 227, 'just': 228, 'place': 229, 'called': 230, 'saw': 231, 'found': 232, 'nothing': 233, 'another': 234, 'towards': 235, 'll': 236, 'poor': 237, 'thy': 238, 'make': 239, 'times': 240, 'heard': 241, 'body': 242, 'along': 243, 'high': 244, 'flask': 245, 'stand': 246, 'sight': 247, 'moment': 248, 'voyage': 249, 'sun': 250, 'sail': 251, 'end': 252, 'new': 253, 'strange': 254, 'hold': 255, 'went': 256, 'shall': 257, 'nantucket': 258, 'years': 259, 'leviathan': 260, 'face': 261, 'get': 262, 'however': 263, '--"': 264, 'does': 265, 'few': 266, 'because': 267, 'black': 268, 'dead': 269, 'whether': 270, 'heart': 271, 'am': 272, 'also': 273, 'stood': 274, 'death': 275, 'oil': 276, 'certain': 277, 'arm': 278, 'going': 279, 'perhaps': 280, 'indeed': 281, 'leg': 282, 'eye': 283, 'true': 284, 'matter': 285, 'iron': 286, 'seems': 287, 'sometimes': 288, 'ships': 289, 'whose': 290, 'seas': 291, 'give': 292, ',--': 293, 'heads': 294, 'seem': 295, 'jonah': 296, 'cabin': 297, 'itself': 298, 'moby': 299, 'dick': 300, 'wild': 301, 'hard': 302, 'soul': 303, 'days': 304, 'standing': 305, 'sailor': 306, 'ocean': 307, 'mind': 308, 'harpooneer': 309, 'land': 310, 'young': 311, 'known': 312, 'tail': 313, 'present ...

# %%
print(model.key_to_index["ship"])
# Out:
# 64

# %%
# To retrieve the single vector representing a given word,
# you can first retrieve its index in the matrix, then access the matrix at that index:

index_to_ship = model.key_to_index["ship"]
model.vectors[index_to_ship]  # vector for the word 'ship'
# Out:
# array([-5.3479511e-01,  2.1575701e-01,  2.9932249e-01, -2.6388153e-01,
#         1.9560806e-01, -1.1302031e+00,  4.2361087e-01,  1.8152790e+00,
#        -9.0721041e-01, -1.1368235e+00, -2.5299701e-01, -8.9009637e-01,
#        -2.7933103e-01,  2.7612177e-01,  1.0364114e+00, -4.9855852e-01,
#         8.8830435e-01, -6.4531934e-01, -2.4299756e-02, -1.5669856e+00,
#         5.5409425e-01, -3.1067133e-01,  1.5245042e+00, -7.5148813e-02,
#        -5.9120823e-02,  9.7965546e-02, -8.3629274e-01,  8.5009849e-01,
#        -4.4590375e-01,  7.2905695e-01,  5.8387685e-01, -2.6368067e-01,
#        -2.5799045e-01, -1.3495766e+00,  3.7397924e-01,  1.2109098e+00,
#         2.3979536e-01, -4.3455276e-01, -3.1702462e-01, -3.1149110e-01,
#         1.6948774e-01, -9.2344791e-01, -2.6366481e-01,  2.9610574e-01,
#         3.0975753e-01, -1.5125133e-01, -1.7254284e-01, -3.2945821e-01,
#         7.6121151e-02,  5.7788432e-01,  5.2769059e-01, -4.3943635e-01,
#         1.7053474e-01, -2.8021140e-02, -5.2347219e-01, -3.2560661e-02,
#         3.9066467e-03,  3.6471829e-01, -3.2051533e-01,  2.5510666e-01,
#         3.6465040e-01, -3.4196693e-01,  2.5828925e-01,  9.6724974e-03,
#        -4.3258506e-01,  1.0337586e+00,  3.7644294e-01,  7.1983021e-01,
#        -2.2472981e-01,  2.9315111e-01,  3.0920854e-01,  6.4833486e-01,
#         5.2070886e-01,  2.2413334e-01,  5.4895192e-01,  2.3118560e-01,
#        -5.2861655e-01,  6.0303783e-01, -2.6590618e-01,  3.5385281e-01,
#        -4.5276874e-01,  1.5968471e-04, -8.8972050e-01,  4.7888222e-01,
#        -3.5545188e-01, -2.9241776e-01,  8.2034874e-01,  2.8192732e-02,
#         4.4983548e-01,  5.0837302e-01,  1.1752222e+00,  7.8301422e-02,
#        -1.3071391e-01, -9.5005155e-02,  1.3822510e+00,  8.0688721e-01,
#         2.0575890e-01, -1.3603133e+00,  3.6204475e-01, -5.3993297e-01],
#       dtype=float32)

# %%
# This is another way to retrieve the vector of a word.
model['ship']
# Out:
# array([-5.3479511e-01,  2.1575701e-01,  2.9932249e-01, -2.6388153e-01,
#         1.9560806e-01, -1.1302031e+00,  4.2361087e-01,  1.8152790e+00,
#        -9.0721041e-01, -1.1368235e+00, -2.5299701e-01, -8.9009637e-01,
#        -2.7933103e-01,  2.7612177e-01,  1.0364114e+00, -4.9855852e-01,
#         8.8830435e-01, -6.4531934e-01, -2.4299756e-02, -1.5669856e+00,
#         5.5409425e-01, -3.1067133e-01,  1.5245042e+00, -7.5148813e-02,
#        -5.9120823e-02,  9.7965546e-02, -8.3629274e-01,  8.5009849e-01,
#        -4.4590375e-01,  7.2905695e-01,  5.8387685e-01, -2.6368067e-01,
#        -2.5799045e-01, -1.3495766e+00,  3.7397924e-01,  1.2109098e+00,
#         2.3979536e-01, -4.3455276e-01, -3.1702462e-01, -3.1149110e-01,
#         1.6948774e-01, -9.2344791e-01, -2.6366481e-01,  2.9610574e-01,
#         3.0975753e-01, -1.5125133e-01, -1.7254284e-01, -3.2945821e-01,
#         7.6121151e-02,  5.7788432e-01,  5.2769059e-01, -4.3943635e-01,
#         1.7053474e-01, -2.8021140e-02, -5.2347219e-01, -3.2560661e-02,
#         3.9066467e-03,  3.6471829e-01, -3.2051533e-01,  2.5510666e-01,
#         3.6465040e-01, -3.4196693e-01,  2.5828925e-01,  9.6724974e-03,
#        -4.3258506e-01,  1.0337586e+00,  3.7644294e-01,  7.1983021e-01,
#        -2.2472981e-01,  2.9315111e-01,  3.0920854e-01,  6.4833486e-01,
#         5.2070886e-01,  2.2413334e-01,  5.4895192e-01,  2.3118560e-01,
#        -5.2861655e-01,  6.0303783e-01, -2.6590618e-01,  3.5385281e-01,
#        -4.5276874e-01,  1.5968471e-04, -8.8972050e-01,  4.7888222e-01,
#        -3.5545188e-01, -2.9241776e-01,  8.2034874e-01,  2.8192732e-02,
#         4.4983548e-01,  5.0837302e-01,  1.1752222e+00,  7.8301422e-02,
#        -1.3071391e-01, -9.5005155e-02,  1.3822510e+00,  8.0688721e-01,
#         2.0575890e-01, -1.3603133e+00,  3.6204475e-01, -5.3993297e-01],
#       dtype=float32)

# %%
all(model['ship'] == model.vectors[index_to_ship])  # all dimensions of both vectors are equal
# Out:
# True

# %%
# It is possible that the model does not contain a particular word
# this will throw an error: model['brontosaurus']

# %%
# You can check if there is a vector for a particular word in the matrix
# by checking if the word is in the model:
"brontosaurus" in model
# Out:
# False

# %% [markdown]
# ## Vector operations
# You can perform mathematical operations using vectors. Note that a vector sum operation is an element-wise sum over each dimension of the vectors. This is done automatically by numpy when you use the + operator for two multidimensional vectors.

# %%
# This is vector sum operation between the vectors representing the words whale and ship.
u =  model['whale']
v = model['ship']

print(u + v)
# Out:
# [-0.9894191   0.5135592   0.3436381  -0.61548364  0.16338104 -2.409175
#   0.82002664  3.910071   -1.900201   -2.4573154  -0.6966464  -2.00729
#  -0.6042564   0.67899334  2.1929784  -0.751392    2.4077225  -1.4680065
#  -0.0757691  -3.4191718   1.465345   -0.8956136   3.618222    0.08835223
#  -0.13449287  0.30717334 -2.1245227   1.7936044  -0.67535496  1.7065425
#   1.5037527  -0.44266126 -0.26637134 -3.2546444   0.6710346   2.6793716
#   0.8317684  -0.7560692  -0.87681174 -0.57394826  0.27190873 -1.8307052
#  -0.4633733   0.5476783   0.6039791  -0.30365664 -0.5960826  -0.719858
#   0.08142173  1.4632695   0.8753939  -0.7832507   0.18965001  0.11852127
#  -1.18103    -0.2055049   0.09887406  0.7362989  -0.6653049   0.72011745
#   0.8303311  -0.98679197  0.54711616  0.21666503 -0.97766626  1.990815
#   0.42674875  1.2748637   0.01819636  0.52905226  0.8826692   1.1557195
#   0.9678828   0.7898922   1.209671    0.36379656 -1.04229     1.4852154
#  -0.4105671   0.7953483  -0.9193225  -0.10872215 -1.8968718   1.2274616
#  -1.0126529  -0.8183277   2.0484834   0.1796049   0.78871226  0.8838614
#   2.6277766   0.5018606  -0.5316322  -0.08752713  2.5916443   1.6299696
#   0.08378735 -2.9391327   1.0158901  -0.95529556]

# %%
a = u * v # element-wise multiplication
b = u / v # element-wise division
c = u + v # element-wise sum
d = u - v # element-wise difference
e = u @ v # dot product

print(e)  # look at different results (a through e)
# Out:
# 44.977043

# %%
# Since you can perform mathematical operations using vectors, you are able
# to compute the cosine similarity between two vectors

def cosine_similarity(u, v):
    dot_product = sum(a * b for a, b in zip(u, v))
    norm_u = np.sqrt(sum(a**2 for a in u))
    norm_v = np.sqrt(sum(b**2 for b in v))

    if norm_u * norm_v != 0:  # avoid division by 0
      similarity = dot_product / (norm_u * norm_v)
    else:
      similarity = 0

    return similarity

u =  model['whale']
v = model['ship']
z = model['giraffe']
print("Similarity between 'whale' and 'ship':", cosine_similarity(u, v))
print("Similarity between 'whale' and 'giraffe':", cosine_similarity(u, z))
print("Similarity between 'ship' and 'giraffe':", cosine_similarity(u, z))
# Out:
# Similarity between 'whale' and 'ship': 0.9652634255083115
# Similarity between 'whale' and 'giraffe': 0.44023588064155317
# Similarity between 'ship' and 'giraffe': 0.44023588064155317

# %%
# Use the 'plot_vectors' helper function to plot the vectors for 'whale', 'ship', and 'giraffe'.

X = np.stack([u,v,z], axis=0)  # stack the three vectors vertically
print(X.shape)
# Out:
# (3, 100)

# %%
plot_vectors(X=X, annotations=["whale", "ship", "giraffe"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5ca3c96b-b563-4680-9f54-2b4f1b29e885" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ca3c96b-b563-4680-9f54-2b4f1b29e885")) {                    Plotly.newPlot(                        "5ca3c96b-b563-4680-9f54-2b4f1b29e885",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["whale","ship","giraffe"],"x":[219.90179443359375,178.8571319580078,116.70578002929688],"xaxis":"x","y":[-210.1395263671875,-149.88330078125,-58.64249801635742],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}} ...

# %%
w2v_vectors = gensim.downloader.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
u = w2v_vectors['king']
v = w2v_vectors['man']
z = w2v_vectors['woman']
x = w2v_vectors['queen']
uvz = u - v + z

print("Similarity between 'king' and 'queen':", cosine_similarity(u, x))
print("Similarity between 'king - man + woman' and 'queen':", cosine_similarity(uvz, x))
print("Similarity between 'king - man + woman' and 'king':", cosine_similarity(uvz, u))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c391c1203298> in <cell line: 1>()
# ----> 1 u = glove_vectors['king']
#       2 v = glove_vectors['man']
#       3 z = glove_vectors['woman']
#       4 x = glove_vectors['queen']
#       5 uvz = u - v + z
#
# NameError: name 'glove_vectors' is not defined

# %%
# Use the 'plot_vectors' helper function to plot the vectors for 'king', 'queen', 'man', 'woman' and 'king - man + woman'.

X = np.stack([u,v,z,x,uvz], axis=0)  # stack the three vectors vertically
print(X.shape)

plot_vectors(X=X, annotations=["king", "man", "woman", "queen", "k - m + w"])
# Out:
# (5, 300)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="844408cd-74e6-452e-8bbe-0249cbcf6498" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("844408cd-74e6-452e-8bbe-0249cbcf6498")) {                    Plotly.newPlot(                        "844408cd-74e6-452e-8bbe-0249cbcf6498",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["king","man","woman","queen","k - m + w"],"x":[-199.57643127441406,25.337570190429688,25.729398727416992,-203.08250427246094,-200.96469116210938],"xaxis":"x","y":[-78.31863403320312,231.8862762451172,225.46212768554688,-94.7326889038086,-84.81776428222656],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{" ...

# %% [markdown]
# ## Task 1: Write your own "most_similar" method.
# Write your own function to retrieve the topn most similar words to a given word.
# Return a list of tuples containing (word, similarity) in the same format as the model.most_similar method.
#
# note: remember that the most similar word is always itself, and you don't need to include it.

# %%
# By computing the similarity between vectors, we can retrieve the top n most similar words
# to a given word.

topn = 50
sims = model.most_similar('ship', topn=topn) # get the most similar words
sims

# This method returns the top n most similar words to the given word, along
# with their cosine similarities.
# Out:
# [('boat', 0.9954759478569031),
#  ('head', 0.9908145070075989),
#  ('stern', 0.9850643873214722),
#  ('pequod', 0.9827502369880676),
#  ('hunter', 0.9799879193305969),
#  ('white', 0.9794375896453857),
#  ('sperm', 0.9767754077911377),
#  ('greenland', 0.9739626049995422),
#  ('mouth', 0.9725837707519531),
#  ('front', 0.9707720875740051),
#  ('level', 0.9705278873443604),
#  ('compass', 0.9699332118034363),
#  ('crew', 0.9694497585296631),
#  ('cap', 0.968940258026123),
#  ('foremost', 0.9685385823249817),
#  ('trunk', 0.9685343503952026),
#  ('line', 0.9678851962089539),
#  ('sweeping', 0.9678312540054321),
#  ('forge', 0.9676457047462463),
#  ('hump', 0.9669303297996521),
#  ('deck', 0.9668094515800476),
#  ('hoisted', 0.9663863778114319),
#  ('cabin', 0.9662346839904785),
#  ('prow', 0.965645432472229),
#  ('quarter', 0.9654600024223328),
#  ('whale', 0.9652633666992188),
#  ('like', 0.9648983478546143),
#  ('world', 0.9646705985069275),
#  ('forecastle', 0.9646473526954651),
#  ('position', 0.9644079208374023),
#  ('top', 0.9638211727142334),
#  ('bar', 0.9635884761810303),
#  ('bottom', 0.9627094268798828),
#  ('back', 0.9625063538551331),
#  ('possession', 0.9624334573745728),
#  ('obliquely', 0.9620397686958313),
#  ('boiling', 0.9619699716567993),
#  ('discovery', 0.9617605805397034),
#  ('works', 0.9607714414596558),
#  ('side', 0.960688591003418),
#  ('tail', 0.960538387298584),
#  ('snow', 0.9602194428443909),
#  ('milky', 0.9601196646690369),
#  ('feeding', 0.9597035050392151),
#  ('hanging', 0.9593297243118286),
#  ('pike', 0.9592464566230774),
#  ('cross', 0.9585291147232056),
#  ('voyage', 0.9585270285606384),
#  ('bone', 0.9584689140319824),
#  ('bag', 0.9581758379936218)]

# %%
# Write your own function to retrieve the topn most similar words to a given word.
# Return a list of tuples containing (word, similarity) in the same format
# as the model.most_similar method.
# note: remember that the most similar word is always itself, and you don't need to include it.

def get_top_similar_words(model, word, topn):
  # YOUR CODE HERE

  ### remove this
  u = model[word]
  similarities = {}
  for w, idx in model.key_to_index.items():
    if w != word:
      v = model[w]
      sim = cosine_similarity(u, v)
      similarities[w] = sim

  top_similar_words = sorted(similarities.items(), key=lambda x: x[1], reverse=True)[:topn]
  ###

  return top_similar_words  # list of tuples with (word, similarity)


top_words = get_top_similar_words(model, "ship", 50)
top_words
# Out:
# [('boat', 0.9954760705362932),
#  ('head', 0.990814545358662),
#  ('stern', 0.985064397312381),
#  ('pequod', 0.9827502114849352),
#  ('hunter', 0.9799878959847372),
#  ('white', 0.9794375301330911),
#  ('sperm', 0.9767754084567828),
#  ('greenland', 0.973962547385929),
#  ('mouth', 0.9725837628335543),
#  ('front', 0.9707720213548349),
#  ('level', 0.9705278733045715),
#  ('compass', 0.9699331895700063),
#  ('crew', 0.9694497997328039),
#  ('cap', 0.968940285351206),
#  ('foremost', 0.9685385624410947),
#  ('trunk', 0.9685343345524855),
#  ('line', 0.9678851617379907),
#  ('sweeping', 0.9678313809905541),
#  ('forge', 0.9676457635198835),
#  ('hump', 0.9669303648127532),
#  ('deck', 0.9668095367079343),
#  ('hoisted', 0.9663863498343828),
#  ('cabin', 0.9662346416460543),
#  ('prow', 0.9656455086952079),
#  ('quarter', 0.9654599895184579),
#  ('whale', 0.9652634255083115),
#  ('like', 0.9648983285192057),
#  ('world', 0.9646705677752866),
#  ('forecastle', 0.9646473681718531),
#  ('position', 0.9644078454900775),
#  ('top', 0.9638211412166906),
#  ('bar', 0.9635884639986678),
#  ('bottom', 0.9627094902434011),
#  ('back', 0.9625062728299292),
#  ('possession', 0.9624334232428474),
#  ('obliquely', 0.9620396828796354),
#  ('boiling', 0.9619699928445546),
#  ('discovery', 0.9617605629074241),
#  ('works', 0.9607714564871926),
#  ('side', 0.9606884900811482),
#  ('tail', 0.9605383643692943),
#  ('snow', 0.9602194320002044),
#  ('milky', 0.960119678155903),
#  ('feeding', 0.9597034931302706),
#  ('hanging', 0.9593296901928158),
#  ('pike', 0.9592464698319674),
#  ('cross', 0.9585290542428134),
#  ('voyage', 0.9585269146797641),
#  ('bone', 0.9584688738801693),
#  ('bag', 0.9581759384274761)]

# %%
# Is your implementation retrieving the exact same words as gensim's implementation?
all([t1[0] == t2[0] for t1, t2 in zip(top_words, sims)])
# Out:
# True

# %%
# Plot the top n similar words.
# Note that this plot is a 2D representation of the 100-dimensional vectors,
# thus it is possible that you see slight differences from what your similarity
# scores indicated.

your_top_words = [w for w, _ in top_words]
vectors = np.stack([model[w] for w in your_top_words])
plot_vectors(vectors, your_top_words)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="91bcdff4-9ebf-4237-91e8-c4cd55755bbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91bcdff4-9ebf-4237-91e8-c4cd55755bbd")) {                    Plotly.newPlot(                        "91bcdff4-9ebf-4237-91e8-c4cd55755bbd",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["boat","head","stern","pequod","hunter","white","sperm","greenland","mouth","front","level","compass","crew","cap","foremost","trunk","line","sweeping","forge","hump","deck","hoisted","cabin","prow","quarter","whale","like","world","forecastle","position","top","bar","bottom","back","possession","obliquely","boiling","discovery","works","side","tail","snow","milky","feeding","hanging","pike","cross","voyage","bone","bag"],"x":[-42.38603591918945,-53.11994934082031,79.18568420410156,-205.27957153320312,-84.03515625,4.149296283721924,6.051721096038818,58.46223449707031,93.04828643798828,-297.47003173828125,106.74606323242188,156.55862426757812,21.998870849609375,-882.395263671875,204.40122985839844,-94.62632751464844,-169.8668670654297,-93.25595092773438,-131.1839599609375,121.74767303466797,-162.80043029785156,90.00701141357422,74.95001220703125,-60.93975830078125,27.330541610717773,-25.876781463623047,1.2118120193481445,-194.673828125,-12.251415252685547,-75.5186767578125,85.82234954833984,937.0650024414062,42.02064895629883,-182.72698974609375,-104.0086669921875,190.50775146484375,-53.70736312866211,-69.74321746826172,280.2040100097656,-152.74908447265625,56.215476989746094,-7.299437999725342,-69.65628814697266,-90.42365264892578,107.78516387939453,176.2796630859375,-547.4839477539062,38.35398864746094,77.19922637939453,190.5955047607422],"xaxis":"x","y":[2.6557681560516357,-1.2063041925430298,12.044910430908203,-31.950456619262695,113.08983612060547,-128.13595581054688,-139.03903198242188,-16.001827239990234,-15.162111282348633,-175.6925811767578,-109.53775787353516,168.13858032226562,124.50304412841797,-36.294307708740234,4.018041610717773,214.64967346191406,11.827555656433105,-102.89851379394531,159.43179321289062,-121.66934967041016,21.42975616455078,-119.26303100585938,108.76514434814453,71.76493072509766,-34.05004119873047,8.661046028137207,-113.90721893310547,-18.627155303955078,185.45204162597656,97.56708526611328,105.22985076904297,1325.3818359375,-25.273672103881836,-4.116355895996094,-77.83360290527344,-5.100595474243164,-78.31387329101562,87.24137878417969,-18.852012634277344,36.45518493652344,114.64385223388672,200.48193359375,-84.24340057373047,-91.54988861083984,-97.85010528564453,-13.770760536193848,730.2085571289062,119.96064758300781,-6.139059543609619,-1001.0069580078125],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666 ...

# %% [markdown]
# ## Part 2: Text classification with embeddings
#
# In this section we will use embeddings that were precomputed by researchers at Stanford. The Glove embeddings we will use were trained on a twitter corpus with a total of 27 billion tokens and a vocabulary size of more than 1 million unique tokens.
# You can read more about it at https://nlp.stanford.edu/projects/glove/.

# %%
# Download and unzip the pretrained embeddings if you don't already have it
# Note: this can take a few minutes
# !wget https://nlp.stanford.edu/data/glove.twitter.27B.zip
# !unzip glove.twitter.27B.zip
# Out:
# --2023-12-07 13:58:42--  https://nlp.stanford.edu/data/glove.twitter.27B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.twitter.27B.zip [following]
# --2023-12-07 13:58:43--  https://downloads.cs.stanford.edu/nlp/data/glove.twitter.27B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1520408563 (1.4G) [application/zip]
# Saving to: ‘glove.twitter.27B.zip’
#
# glove.twitter.27B.z 100%[===================>]   1.42G  5.12MB/s    in 4m 46s
#
# 2023-12-07 14:03:30 (5.06 MB/s) - ‘glove.twitter.27B.zip’ saved [1520408563/1520408563]
#
# Archive:  glove.twitter.27B.zip
#   inflating: glove.twitter.27B.25d.txt
#   inflating: glove.twitter.27B.50d.txt
#   inflating: glove.twitter.27B.100d.txt
#   inflating: glove.twitter.27B.200d.txt

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
import pandas as pd

# %%
# Load the embeddings as a gensim model (this can take a few seconds)
glove_input_file = 'glove.twitter.27B.100d.txt'
model = KeyedVectors.load_word2vec_format(glove_input_file, binary=False, no_header=True)

# %%
model.vectors.shape
# Out:
# (1193514, 100)

# %%
# Note how the top similar words are different from the embeddings we trained previously.
sims = model.most_similar("ship", topn=5)
sims
# Out:
# [('ships', 0.822455108165741),
#  ('boat', 0.6777802109718323),
#  ('shipping', 0.6437048316001892),
#  ('larry', 0.6169042587280273),
#  ('narry', 0.602217435836792)]

# %%
# Plot the most similar words to 'whale' in the glove vector space
words = [w for w, _ in sims]
vectors = np.stack([model[w] for w in words], axis=0)

plot_vectors(vectors, words)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7a8cedbe-517d-4393-8b3f-86b8308a1817" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a8cedbe-517d-4393-8b3f-86b8308a1817")) {                    Plotly.newPlot(                        "7a8cedbe-517d-4393-8b3f-86b8308a1817",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eword=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":["ships","boat","shipping","larry","narry"],"x":[223.59693908691406,224.0287322998047,222.9390411376953,-155.21934509277344,-155.212646484375],"xaxis":"x","y":[50.764888763427734,44.1038932800293,60.92643356323242,-61.322723388671875,-54.85770034790039],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line ...

# %% [markdown]
# ## Sentiment Classification
# We will train a machine learning model to predict the sentiment of tweets associated with airline companies. We will use the embeddings of the tweets as features.
#
# **Please upload the Tweets_short.csv file in this notebook.** You can click the folder option "Files" in the left part of the UI, and then "Upload to session storage", or simply drag and drop the file.

# %%
import re
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from nltk.tokenize import word_tokenize

# %%
df = pd.read_csv("Tweets_short.csv")
df
# Out:
#                  tweet_id airline_sentiment  \
# 0      570306133677760513           neutral
# 1      570301130888122368          positive
# 2      570301083672813571           neutral
# 3      570301031407624196          negative
# 4      570300817074462722          negative
# ...                   ...               ...
# 14635  569587686496825344          positive
# 14636  569587371693355008          negative
# 14637  569587242672398336           neutral
# 14638  569587188687634433          negative
# 14639  569587140490866689           neutral
#
#                                                     text
# 0                    @VirginAmerica What @dhepburn said.
# 1      @VirginAmerica plus you've added commercials t...
# 2      @VirginAmerica I didn't today... Must mean I n...
# 3      @VirginAmerica it's really aggressive to blast...
# 4      @VirginAmerica and it's a really big bad thing...
# ...                                                  ...
# 14635  @AmericanAir thank you we got on a different f...
# 14636  @AmericanAir leaving over 20 minutes Late Flig...
# 14637  @AmericanAir Please bring American Airlines to...
# 14638  @AmericanAir you have my money, you change my ...
# 14639  @AmericanAir we have 8 ppl so we need 2 know h...
#
# [14640 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['tweet_id'].plot(kind='hist', bins=20, title='tweet_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('airline_sentiment').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['tweet_id'].plot(kind='line', figsize=(8, 4), title='tweet_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['airline_sentiment'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='tweet_id', y='airline_sentiment', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# Distribution of classes
df["airline_sentiment"].value_counts()
# Out:
# negative    9178
# neutral     3099
# positive    2363
# Name: airline_sentiment, dtype: int64

# %% [markdown]
# ## Task 2:
# Implement normalisation and tokenisation for the dataset. The Glove embeddings we are going to use were trained by mapping hashtags to the token \<hashtag>, numbers to the token \<number>, urls to \<url>, and @users to \<user>. Also,  all tokens should be lowercased.
#
# The full list of normalisations can be found at https://nlp.stanford.edu/projects/glove/preprocess-twitter.rb. You don't need to implement all normalisation steps. You can play around and see how the performance of your model is affected by extra normalisation steps.

# %%
def normalise_tweet(tweet):
  ### YOUR CODE HERE

  ### Remove
  # Replace @ with "<USER>"
  tweet = re.sub(r'@(\w+)', r'<USER>', tweet)
  # Replace numbers with "<NUMBER>"
  tweet = re.sub(r'\b\d+\b', r'<NUMBER>', tweet)
  # Replace hashtags with "<HASHTAG>"
  tweet = re.sub(r'#(\w+)', r'<HASHTAG>', tweet)

  ###

  return tweet

def tokenise_tweet(tweet):
  ### Your code here.

  ### Remove
  tweet = tweet.split()
  return tweet

# %%
mapping = {"neutral": 0, "negative": -1, "positive": 1}
labels = df["airline_sentiment"].apply(lambda x: mapping[x]).to_numpy()  # convert the sentiment labels to 0, -1, and 1.
text = (df["text"].apply(lambda x: normalise_tweet(x))  # normalise
  .apply(lambda x: tokenise_tweet(x)).tolist())  # tokenise

# %% [markdown]
# ## Task 3:
# Implement a function to compute the embedding of a SENTENCE. Up until now we were working with WORD embeddings. Now you have to produce a single vector to represent the whole sentence. There are many ways to aggregate the word vectors into a sentence vector. We will implement a simple averaging method across the embeddings of each word in the sentence.
#
# Your function should sum the embeddings of the words in the tweet, and divide this vector by the number of tokens in the tweet.
#
# Remember to check if a word is in the model before retrieving it. Assign a vector of zeros if the word is not in the model: np.zeros(100).

# %%
def get_tweet_embedding(tweet_tokenised):
  ### YOUR CODE HERE

  ### remove
  num_tokens = len(tweet_tokenised)
  tweet_embedding = np.zeros(100)
  for token in tweet_tokenised:
    if token in model:
      token_embedding = model[token]
    else:
      token_embedding = np.zeros(100)

    tweet_embedding += token_embedding
  tweet_embedding = tweet_embedding / num_tokens
  ###


  return tweet_embedding

# %%
# Stack the tweet embeddings into a matrix X
X = []
for tokenised_tweet in text:
  tweet_embedding = get_tweet_embedding(tokenised_tweet)
  X.append(tweet_embedding)

X = np.stack(X)
X.shape
# Out:
# (14640, 100)

# %%
# We will use the tweet embeddings to train a classifier to predict if a given tweet
# has a positive, neutral, or negative sentiment.
print("Sentence embeddings:", X)
print("Labels:", labels)
# Out:
# Sentence embeddings: [[ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [ 0.21257911  0.02539834  0.08507999 ... -0.17630889  0.03601556
#   -0.00290734]
#  [ 0.0948785   0.1269825   0.13309833 ... -0.02690358  0.11355667
#    0.02367333]
#  ...
#  [ 0.12804214  0.10400286  0.14454857 ...  0.00779986  0.01965972
#    0.07346143]
#  [ 0.06316761  0.09350109  0.04734465 ... -0.08208696  0.1293707
#    0.01190987]
#  [ 0.1694817   0.23913843  0.05472    ... -0.10046117  0.14236663
#    0.03474223]]
# Labels: [ 0  1  0 ...  0 -1  0]

# %%
# Split the data into train and test sets
train_idxs, test_idxs = train_test_split(range(len(df)), train_size=0.7, random_state=42, stratify=labels)

X_train = X[train_idxs]
X_test = X[test_idxs]

y_train = labels[train_idxs]
y_test = labels[test_idxs]

# %%
# Train the classifier
clf = SVC(random_state=42, class_weight="balanced")
clf.fit(X_train, y_train);

# %%
# Make predictions on the test set
predictions = clf.predict(X_test)
predictions
# Out:
# array([ 1, -1, -1, ...,  1,  1, -1])

# %%
# Score the classifier
accuracy = accuracy_score(predictions, y_test)
f1_macro = f1_score(predictions, y_test, average="macro")
print(f"Accuracy: {accuracy*100:.2f}/100")
print(f"F1-Macro: {f1_macro*100:.2f}/100")
# Out:
# Accuracy: 67.55/100
# F1-Macro: 62.01/100

# %% [markdown]
# ## Task 4:
# Perform error analysis. Analyse the tweets that were incorrectly classified by your model. Explore the types of mistakes your classifier made. How many negative tweets did it predict as positive? and neutral?
#
# Take a look at [confusion matrices](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) and try to use sklearn's implementation in your analysis.

# %%
# Analyse the tweets that were incorrectly classified by your model
misclassified_idxs = np.array(test_idxs)[predictions != y_test]

pred_df = df.iloc[test_idxs].reset_index()
pred_df["predicted_sentiment"] = predictions

reverse_mapping = {v: k for k, v in mapping.items()}
pred_df["predicted_sentiment"] = pred_df["predicted_sentiment"].apply(lambda x: reverse_mapping[x])
mistakes_df = pred_df[pred_df["index"].isin(misclassified_idxs)]
mistakes_df
# Out:
#       index            tweet_id airline_sentiment  \
# 0     12814  570010327036735488          negative
# 4     10782  568881148325007360           neutral
# 6     14575  569596793941401601          negative
# 8       857  570050268588597248          negative
# 20    10709  568959416524886016          negative
# ...     ...                 ...               ...
# 4367   8991  570296273611448320          negative
# 4369   2118  569361701495304192           neutral
# 4372   6517  567805714216792064          negative
# 4376   4831  569691144897953793          negative
# 4390  10422  569317626687717376          negative
#
#                                                    text predicted_sentiment
# 0     @AmericanAir I'll try to have a great week onc...            positive
# 4                        @USAirways Yes, it was Sunday.            positive
# 6     @AmericanAir don't you guys have an email addr...             neutral
# 8     @united can you tell me how to file a claim fo...             neutral
# 20    @USAirways Already tried. How about Conf # via DM             neutral
# ...                                                 ...                 ...
# 4367  @USAirways I have two tight connections in #Ch...            positive
# 4369  @united just called and did it. Should have ea...            negative
# 4372  @SouthwestAir my pts expired. I made a prchase...            positive
# 4376  @SouthwestAir A-list preferred. DEN-DAL flight...             neutral
# 4390  @USAirways Still waiting for another crew memb...            positive
#
# [1425 rows x 5 columns]

# %%
condition = mistakes_df["airline_sentiment"] == "negative"
mistakes_df[condition]
# Out:
#       index            tweet_id airline_sentiment  \
# 0     12814  570010327036735488          negative
# 6     14575  569596793941401601          negative
# 8       857  570050268588597248          negative
# 20    10709  568959416524886016          negative
# 24     6598  567764010812985344          negative
# ...     ...                 ...               ...
# 4363  14135  569662471213948928          negative
# 4367   8991  570296273611448320          negative
# 4372   6517  567805714216792064          negative
# 4376   4831  569691144897953793          negative
# 4390  10422  569317626687717376          negative
#
#                                                    text predicted_sentiment
# 0     @AmericanAir I'll try to have a great week onc...            positive
# 6     @AmericanAir don't you guys have an email addr...             neutral
# 8     @united can you tell me how to file a claim fo...             neutral
# 20    @USAirways Already tried. How about Conf # via DM             neutral
# 24    @SouthwestAir I recommend upgrading your IVR a...             neutral
# ...                                                 ...                 ...
# 4363  @AmericanAir AA 100 - good job overselling thi...            positive
# 4367  @USAirways I have two tight connections in #Ch...            positive
# 4372  @SouthwestAir my pts expired. I made a prchase...            positive
# 4376  @SouthwestAir A-list preferred. DEN-DAL flight...             neutral
# 4390  @USAirways Still waiting for another crew memb...            positive
#
# [803 rows x 5 columns]
